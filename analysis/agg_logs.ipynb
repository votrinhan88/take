# %%
# Change path
import os, sys
repo_path = os.path.abspath(os.path.join(os.path.abspath(''), '..'))
assert os.path.basename(repo_path) == 'textdd', "Wrong parent folder. Please change to 'textdd'"
if sys.path[0] != repo_path:
    sys.path.insert(0, repo_path)

from agg_lightning_logs import aggregate_lightning_logs

# %%
aggregate_lightning_logs(
    input_dir=f'../logs/clf-logistic-tfidf-imdb',
    output_dir=f'../results/clf/imdb/clf-logistic-tfidf-imdb/eda/',
    delete=True,
    verbose=True,
)
# Out:
# Done: ../logs/clf-logistic-tfidf-imdb/eda-v0/logs/version_0/metrics.csv --> ../results/clf/imdb/clf-logistic-tfidf-imdb/eda/clf-logistic-tfidf-imdb - run eda-v0.csv
# Done: ../logs/clf-logistic-tfidf-imdb/eda-v1/logs/version_0/metrics.csv --> ../results/clf/imdb/clf-logistic-tfidf-imdb/eda/clf-logistic-tfidf-imdb - run eda-v1.csv
# Done: ../logs/clf-logistic-tfidf-imdb/eda-v2/logs/version_0/metrics.csv --> ../results/clf/imdb/clf-logistic-tfidf-imdb/eda/clf-logistic-tfidf-imdb - run eda-v2.csv
# Done: ../logs/clf-logistic-tfidf-imdb/eda-v3/logs/version_0/metrics.csv --> ../results/clf/imdb/clf-logistic-tfidf-imdb/eda/clf-logistic-tfidf-imdb - run eda-v3.csv
# Done: ../logs/clf-logistic-tfidf-imdb/eda-v4/logs/version_0/metrics.csv --> ../results/clf/imdb/clf-logistic-tfidf-imdb/eda/clf-logistic-tfidf-imdb - run eda-v4.csv
# Deleted: ../logs/clf-logistic-tfidf-imdb
